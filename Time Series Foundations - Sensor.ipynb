# %% [markdown]
# ## Import Packages and Data

# %%
# Data from https://www.kaggle.com/datasets/nphantawee/pump-sensor-data

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sensor_df = pd.read_csv("sensor.csv")

# %% [markdown]
# ## Explore Data

# %%
sensor_df.head()
# Out:
#    Unnamed: 0            timestamp  sensor_00  sensor_01  sensor_02  \
# 0           0  2018-04-01 00:00:00   2.465394   47.09201    53.2118
# 1           1  2018-04-01 00:01:00   2.465394   47.09201    53.2118
# 2           2  2018-04-01 00:02:00   2.444734   47.35243    53.2118
# 3           3  2018-04-01 00:03:00   2.460474   47.09201    53.1684
# 4           4  2018-04-01 00:04:00   2.445718   47.13541    53.2118
#
#    sensor_03  sensor_04  sensor_05  sensor_06  sensor_07  ...  sensor_43  \
# 0  46.310760   634.3750   76.45975   13.41146   16.13136  ...   41.92708
# 1  46.310760   634.3750   76.45975   13.41146   16.13136  ...   41.92708
# 2  46.397570   638.8889   73.54598   13.32465   16.03733  ...   41.66666
# 3  46.397568   628.1250   76.98898   13.31742   16.24711  ...   40.88541
# 4  46.397568   636.4583   76.58897   13.35359   16.21094  ...   41.40625
#
#    sensor_44  sensor_45  sensor_46  sensor_47  sensor_48  sensor_49  \
# ...

# %%
sensor_df.describe()
# Out:
#           Unnamed: 0      sensor_00      sensor_01      sensor_02  \
# count  220320.000000  210112.000000  219951.000000  220301.000000
# mean   110159.500000       2.372221      47.591611      50.867392
# std     63601.049991       0.412227       3.296666       3.666820
# min         0.000000       0.000000       0.000000      33.159720
# 25%     55079.750000       2.438831      46.310760      50.390620
# 50%    110159.500000       2.456539      48.133678      51.649300
# 75%    165239.250000       2.499826      49.479160      52.777770
# max    220319.000000       2.549016      56.727430      56.032990
#
#            sensor_03      sensor_04      sensor_05      sensor_06  \
# count  220301.000000  220301.000000  220301.000000  215522.000000
# mean       43.752481     590.673936      73.396414      13.501537
# std         2.418887     144.023912      17.298247       2.163736
# min        31.640620       2.798032       0.000000       0.014468
# ...

# %%
sensor_df.isna().sum()
# Out:
# Unnamed: 0             0
# timestamp              0
# sensor_00          10208
# sensor_01            369
# sensor_02             19
# sensor_03             19
# sensor_04             19
# sensor_05             19
# sensor_06           4798
# sensor_07           5451
# sensor_08           5107
# sensor_09           4595
# sensor_10             19
# sensor_11             19
# sensor_12             19
# sensor_13             19
# sensor_14             21
# sensor_15         220320
# sensor_16             31
# sensor_17             46
# sensor_18             46
# sensor_19             16
# sensor_20             16
# sensor_21             16
# sensor_22             41
# sensor_23             16
# sensor_24             16
# sensor_25             36
# sensor_26             20
# sensor_27             16
# sensor_28             16
# sensor_29             72
# sensor_30            261
# sensor_31             16
# sensor_32             68
# sensor_33             16
# sensor_34             16
# ...

# %%
sensor_df = sensor_df[['timestamp','sensor_03']]

# %%
sensor_df.head()
# Out:
#              timestamp  sensor_03
# 0  2018-04-01 00:00:00  46.310760
# 1  2018-04-01 00:01:00  46.310760
# 2  2018-04-01 00:02:00  46.397570
# 3  2018-04-01 00:03:00  46.397568
# 4  2018-04-01 00:04:00  46.397568

# %% [markdown]
# ## Create Timeseries Object

# %%
sensor_df['timestamp'] = pd.to_datetime(sensor_df['timestamp'])
sensor_df.set_index('timestamp',inplace=True)
sensor_df.head()
# Out:
#                      sensor_03
# timestamp
# 2018-04-01 00:00:00  46.310760
# 2018-04-01 00:01:00  46.310760
# 2018-04-01 00:02:00  46.397570
# 2018-04-01 00:03:00  46.397568
# 2018-04-01 00:04:00  46.397568

# %%
sensor_df = sensor_df.asfreq('h')
sensor_df.isna().sum()
# Out:
# sensor_03    0
# dtype: int64

# %% [markdown]
# (No missing values to impute)

# %% [markdown]
# ## Plotting the Data

# %%
sensor_df.plot(figsize=(20,5))
plt.title("Sensor 03 Trend",size = 20)
plt.show()

# %% [markdown]
# ## Train-Test Splits

# %%
size = int(len(sensor_df)*0.8)
sensor_train = sensor_df.iloc[:size]
sensor_test = sensor_df.iloc[size:]

# %%
sensor_train.tail()
# Out:
#                      sensor_03
# timestamp
# 2018-08-01 04:00:00  44.574650
# 2018-08-01 05:00:00  44.444443
# 2018-08-01 06:00:00  44.661457
# 2018-08-01 07:00:00  44.574650
# 2018-08-01 08:00:00  44.227428

# %%
sensor_test.head()
# Out:
#                      sensor_03
# timestamp
# 2018-08-01 09:00:00  44.270832
# 2018-08-01 10:00:00  44.487846
# 2018-08-01 11:00:00  44.661460
# 2018-08-01 12:00:00  44.921875
# 2018-08-01 13:00:00  45.572914

# %% [markdown]
# ## Export Data

# %%
sensor_train.to_csv("sensor - train.csv")
sensor_test.to_csv("sensor - test.csv")
sensor_df.to_csv("sensor - clean.csv")
